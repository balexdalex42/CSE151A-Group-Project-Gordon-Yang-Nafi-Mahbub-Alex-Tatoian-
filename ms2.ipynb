# %%
import pandas as pd
import numpy as np

# %%
import kagglehub
import os
# Download latest version
path = kagglehub.dataset_download("sakhawat18/asteroid-dataset")

print("Path to dataset files:", path)
print(os.listdir(path))
# Out:
# Path to dataset files: /kaggle/input/asteroid-dataset
# ['dataset.csv']

# %%
# import the dataset

df = pd.read_csv(f"{path}/dataset.csv", low_memory=False)
print(df.head())
# Out:
#          id    spkid       full_name pdes     name prefix neo pha     H  \
# 0  a0000001  2000001         1 Ceres    1    Ceres    NaN   N   N  3.40
# 1  a0000002  2000002        2 Pallas    2   Pallas    NaN   N   N  4.20
# 2  a0000003  2000003          3 Juno    3     Juno    NaN   N   N  5.33
# 3  a0000004  2000004         4 Vesta    4    Vesta    NaN   N   N  3.00
# 4  a0000005  2000005       5 Astraea    5  Astraea    NaN   N   N  6.90
#
#    diameter  ...       sigma_i      sigma_om       sigma_w      sigma_ma  \
# 0   939.400  ...  4.608900e-09  6.168800e-08  6.624800e-08  7.820700e-09
# 1   545.000  ...  3.469400e-06  6.272400e-06  9.128200e-06  8.859100e-06
# 2   246.596  ...  3.223100e-06  1.664600e-05  1.772100e-05  8.110400e-06
# 3   525.400  ...  2.170600e-07  3.880800e-07  1.789300e-07  1.206800e-06
# 4   106.699  ...  2.740800e-06  2.894900e-05  2.984200e-05  8.303800e-06
#
#        sigma_ad       sigma_n      sigma_tp     sigma_per  class      rms
# ...

# %%
# print all the column names of the dataset
df.columns
# Out:
# Index(['id', 'spkid', 'full_name', 'pdes', 'name', 'prefix', 'neo', 'pha', 'H',
#        'diameter', 'albedo', 'diameter_sigma', 'orbit_id', 'epoch',
#        'epoch_mjd', 'epoch_cal', 'equinox', 'e', 'a', 'q', 'i', 'om', 'w',
#        'ma', 'ad', 'n', 'tp', 'tp_cal', 'per', 'per_y', 'moid', 'moid_ld',
#        'sigma_e', 'sigma_a', 'sigma_q', 'sigma_i', 'sigma_om', 'sigma_w',
#        'sigma_ma', 'sigma_ad', 'sigma_n', 'sigma_tp', 'sigma_per', 'class',
#        'rms'],
#       dtype='object')

# %%
# print the size and number of columns in the dataset
df.shape
# Out:
# (958524, 45)

# %%
# check for missing data and find out how many entries are missing data
missing_values = df.isnull()       # returns matrix of boolean T/F values for missing data (True if null)
num_mv = np.sum(missing_values, axis=0)

# print how much data is missing from each column
num_mv
# Out:
# id                     0
# spkid                  0
# full_name              0
# pdes                   0
# name              936460
# prefix            958506
# neo                    4
# pha                19921
# H                   6263
# diameter          822315
# albedo            823421
# diameter_sigma    822443
# orbit_id               0
# epoch                  0
# epoch_mjd              0
# epoch_cal              0
# equinox                0
# e                      0
# a                      0
# q                      0
# i                      0
# om                     0
# w                      0
# ma                     1
# ad                     4
# n                      0
# tp                     0
# tp_cal                 0
# per                    4
# per_y                  1
# moid               19921
# moid_ld              127
# sigma_e            19922
# sigma_a            19922
# sigma_q            19922
# sigma_i            19922
# sigma_om           19922
# ...

# %% [markdown]
# ##Data Plotting

# %%
df.info()
df.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958524 entries, 0 to 958523
# Data columns (total 45 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              958524 non-null  object
#  1   spkid           958524 non-null  int64
#  2   full_name       958524 non-null  object
#  3   pdes            958524 non-null  object
#  4   name            22064 non-null   object
#  5   prefix          18 non-null      object
#  6   neo             958520 non-null  object
#  7   pha             938603 non-null  object
#  8   H               952261 non-null  float64
#  9   diameter        136209 non-null  float64
#  10  albedo          135103 non-null  float64
#  11  diameter_sigma  136081 non-null  float64
#  12  orbit_id        958524 non-null  object
#  13  epoch           958524 non-null  float64
#  14  epoch_mjd       958524 non-null  int64
#  15  epoch_cal       958524 non-null  float64
# ...

# %% [markdown]
# ## **NOTE: We will be graphing/plotting the most applicable data columns and will describe such plots below

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### neo

# %%
counts = df['neo'].value_counts(dropna=False)

# Rename the NaN index for clarity
counts.index = counts.index.fillna('Unknown')

colors = ['red', 'green', 'gray']  # colors
plt.pie(counts, labels=None, colors=colors, startangle=90, wedgeprops={'edgecolor':'white'})

total = counts.sum()
labels = [f"{label}: {count} ({count/total*100:.1f}%)" for label, count in zip(counts.index, counts)]
# Add legend
plt.legend(labels=labels, title="N.E.O State", loc="best")

plt.title("Near Earth Object State")
plt.show()

# %% [markdown]
# This plot describes whether or not the asteroid is a near-earth object (Y for Yes and N for No). Notably there are also some null values as well.

# %% [markdown]
# ### pha

# %%
counts = df['pha'].value_counts(dropna=False)

# Rename the NaN index for clarity
counts.index = counts.index.fillna('Unknown')

colors = ['green', 'red', 'gray']  # colors
plt.pie(counts, labels=None, colors=colors, startangle=90, wedgeprops={'edgecolor':'white'})

total = counts.sum()
labels = [f"{label}: {count} ({count/total*100:.1f}%)" for label, count in zip(counts.index, counts)]
# Add legend
plt.legend(labels=labels, title="P.H.A State", loc="best")

plt.title("Potential Hazardous Asteroid or Not")
plt.show()

# %% [markdown]
# pha describes whether or not the asteroid is a potentially hazardous asteroid or not (Y for Yes and N for No). Notably there are also some null values as well.

# %% [markdown]
# ### diameter

# %%
df['diameter'].hist(bins=200)  # bins = number of intervals
plt.xlabel("Asteroid Diameter (km)")
plt.ylabel("Count")
plt.title("Histogram of Asteroid Diameter Frequencies")
plt.show()

# %% [markdown]
# This graph shows a left skew of asteroid diameters in the dataset. Most notably the asteroid diameters seem to be extremely clustered between 0 and 20 km.

# %% [markdown]
# ### e

# %%
df['e'].hist(bins=200)  # bins = number of intervals
plt.xlabel("Eccentricity")
plt.ylabel("Count")
plt.title("Histogram of Eccentricity region frequencies")
plt.show()

# %% [markdown]
# This graph shows another left skew, where the majority of the data points have eccentricity between 0 and 0.25.

# %% [markdown]
# ### a

# %%
df['a'].hist(bins=200)  # bins = number of intervals
plt.xlabel("Semi-major axis (AU)")
plt.ylabel("Count")
plt.title("Histogram of Semi-major axis region frequencies")
plt.show()

# %% [markdown]
# The semi-major axis is the avg. distance between the asteroid and the Sun. This data is heavily spread (as the very large unit steps), but clearly almost all of the data is averaging around 2.9 AU.

# %% [markdown]
# ### q

# %%
df['q'].hist(bins=200)  # bins = number of intervals
plt.xlabel("perihelion distance (AU)")
plt.ylabel("Count")
plt.title("Histogram of perihelion distance region frequencies")
plt.show()

# %% [markdown]
# The perihelion distance is the closest distance between an asteroid and the Sun in its orbit. We notice that the data centers around 2.39 AU.

# %% [markdown]
# ### moid

# %%
df['moid'].hist(bins=200)  # bins = number of intervals
plt.xlabel("earth minimum orbit intersection distance (au)")
plt.ylabel("Count")
plt.title("Histogram of earth minimum orbit intersection distance region frequencies")
plt.show()

# %% [markdown]
# MOID (Minimum Orbit Intersection Distance) is the smallest distance between an asteroid’s orbit and Earth’s orbit, indicating how close the asteroid can come to our planet. We notice that most of the data is centered around 1.42 AU.

# %% [markdown]
# ### moid_ld

# %%
df['moid_ld'].hist(bins=200)  # bins = number of intervals
plt.xlabel("earth minimum orbit intersection distance lunar unit")
plt.ylabel("Count")
plt.title("Histogram of earth minimum orbit intersection distance (lunar unit) region frequencies")
plt.show()

# %% [markdown]
# This is the same thing as moid, but expressed in lunar units (average Earth-Moon distance).

# %% [markdown]
# class

# %%
counts = df['class'].value_counts(dropna=False)

# Rename the NaN index for clarity
counts.index = counts.index.fillna('Unknown')

plt.pie(counts, labels=None, startangle=90, wedgeprops={'edgecolor':'white'})

total = counts.sum()
labels = [f"{label}: {count} ({count/total*100:.1f}%)" for label, count in zip(counts.index, counts)]
# Add legend
plt.legend(labels=labels, title="Asteroid Class", loc="lower left")

plt.title("Asteroid Class Pie Chart")
plt.show()

# %% [markdown]
# This pi-chart describes the dataset's asteroid classes. We notice that almost all of the asteroids fall under the MBA asteroid type (
